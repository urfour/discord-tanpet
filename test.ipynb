# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url = 'https://tofus.fr/fiches/challenge.php'
challenges_page = requests.get(url)
soup = BeautifulSoup(challenges_page.text, 'html.parser')

# %%
table = soup.find('table')
challenges = [row for row in table.find_all('tr')]
challenges.pop(0)

challenges_dict = []

for row in challenges:
    tr = row.find_all('td')
    challenges_dict.append(
        {'nom': tr[0].get_text(),
        'description': tr[1].get_text()
        }
    )
df = pd.DataFrame.from_dict(challenges_dict)

# %%
df
# Out:
#                        nom                                        description
# 0               Abnégation  Les personnages ne doivent jamais recevoir de ...
# 1               Anachorète  Ne jamais finir son tour sur une cellule adjac...
# 2              Araknophile  Invoquer une Arakne à chaque fois que le sort ...
# 3                  Barbare  Occasionner des dommages avec une arme sur all...
# 4               Blitzkrieg  Dès qu'un adversaire est attaqué, il doit être...
# 5             Casino Royal  Lancer le sort Roulette à chaque fois que le s...
# 6      Chacun son monstre   Chaque personnage doit avoir achevé au moins u...
# 7               Circulez !  Ne pas retirer de PM aux adversaires pendant t...
# 8                  Collant  Finir son tour sur une cellule adjacente à cel...
# 9            Contamination  Dès qu'un allié perd des points de vie ou des ...
# 10                  Cruel   Les adversaires doivent être tués dans l'ordre...
# 11      Désigné volontaire                 Tuer un monstre précis en premier.
# 12  Deux pour le prix d'un  Lorsqu'un personnage achève un adversaire, il ...
# 13                    Duel  Lorsqu'un personnage attaque un adversaire, au...
# 14                 Econome  Tous les personnages ne doivent utiliser qu'un...
# 15             Elémentaire  Utiliser le même élément d'attaque pendant tou...
# 16                Elitiste  Toutes les attaques doivent être concentrées s...
# 17                   Focus  Lorsqu'un adversaire est attaqué, il doit être...
# 18               Fossoyeur  Invoquer un Chaferfu à chaque fois que le sort...
# 19                   Hardi  Finir son tour sur une cellule adjacente à cel...
# 20            Imprévisible  Toutes les attaques doivent être concentrées s...
# 21             Intouchable  Ne pas perdre de point de vie ou de point de b...
# 22               Incurable  Ne pas regagner de points de vie pendant toute...
# 23               Jardinier  Planter une Cawotte à chaque fois que le sort ...
# 24       Les mules d'abord  La mule de plus faible niveau doit achever tou...
# 25      Les petits d'abord  Le personnage de plus petit niveau doit acheve...
# 26      Le temps qui court  Ne pas retirer de PA aux adversaires pendant t...
# 27           Mains propres  Achever tous les monstres sans leur occasionne...
# 28                Mystique  N'utiliser que des sorts pendant toute la duré...
# 29      Ni pious ni soumis  Les personnages de sexe féminin doivent laisse...
# 30  Ni pioutes ni soumises  Les personnages de sexe masculin doivent laiss...
# 31                  Nomade  Utiliser tous ses PM disponibles à chaque tour...
# 32                 Ordonné  Les adversaires doivent être achevés dans l'or...
# 33                 Partage  Chaque personnage doit avoir achevé au moins u...
# 34            Perdu de vue  Ne pas retirer de portée aux adversaires penda...
# 35                Pétulant  Utiliser tous les points d'action disponibles ...
# 36             Pusillanime  Ne jamais finir son tour sur une cellule adjac...
# 37                  Statue  Finir son tour sur la même case que celle où o...
# 38                  Sursis                 Tuer un monstre précis en dernier.
# 39               Survivant  Tous les alliés doivent terminer le combat viv...
# 40            Tueur à gage  Les adversaires doivent être tués dans l'ordre...
# 41               Versatile  Chaque joueur n'a le droit d'effectuer qu'une ...
# 42                  Zombie  Utiliser un seul point de mouvement par tour d...
